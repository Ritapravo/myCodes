# %%
import numpy as np
import pandas as pd

# %%
census = pd.read_csv("census.csv")
census
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 0         50       3         6      1       1  Alabama     Autauga County
# 1         50       3         6      1       3  Alabama     Baldwin County
# 2         50       3         6      1       5  Alabama     Barbour County
# 3         50       3         6      1       7  Alabama        Bibb County
# 4         50       3         6      1       9  Alabama      Blount County
# ...      ...     ...       ...    ...     ...      ...                ...
# 3137      50       4         8     56      37  Wyoming  Sweetwater County
# 3138      50       4         8     56      39  Wyoming       Teton County
# 3139      50       4         8     56      41  Wyoming       Uinta County
# 3140      50       4         8     56      43  Wyoming    Washakie County
# 3141      50       4         8     56      45  Wyoming      Weston County
#
#       CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  \
# ...

# %%
sm = census.iloc[:,5:7]
sm
# Out:
#        STNAME            CTYNAME
# 0     Alabama     Autauga County
# 1     Alabama     Baldwin County
# 2     Alabama     Barbour County
# 3     Alabama        Bibb County
# 4     Alabama      Blount County
# ...       ...                ...
# 3137  Wyoming  Sweetwater County
# 3138  Wyoming       Teton County
# 3139  Wyoming       Uinta County
# 3140  Wyoming    Washakie County
# 3141  Wyoming      Weston County
#
# [3142 rows x 2 columns]

# %%
sm2 = sm.groupby("STNAME")
c1 = sm2.count()
c1
# Out:
#                       CTYNAME
# STNAME
# Alabama                    67
# Alaska                     29
# Arizona                    15
# Arkansas                   75
# California                 58
# Colorado                   64
# Connecticut                 8
# Delaware                    3
# District of Columbia        1
# Florida                    67
# Georgia                   159
# Hawaii                      5
# Idaho                      44
# Illinois                  102
# Indiana                    92
# Iowa                       99
# Kansas                    105
# Kentucky                  120
# Louisiana                  64
# Maine                      16
# Maryland                   24
# Massachusetts              14
# Michigan                   83
# Minnesota                  87
# Mississippi                82
# Missouri                  115
# Montana                    56
# Nebraska                   93
# Nevada                     17
# ...

# %%
max(c1.iloc[:,0])
# Out:
# 254

# %%
n = len(c1.iloc[:,0])
k=0
for i in range(n):
    k+=1
    if(c1.iloc[i,0]==max(c1.iloc[:,0])):
        break
c1.iloc[k-1]
# Out:
# CTYNAME    254
# Name: Texas, dtype: int64

# %%
census
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 0         50       3         6      1       1  Alabama     Autauga County
# 1         50       3         6      1       3  Alabama     Baldwin County
# 2         50       3         6      1       5  Alabama     Barbour County
# 3         50       3         6      1       7  Alabama        Bibb County
# 4         50       3         6      1       9  Alabama      Blount County
# ...      ...     ...       ...    ...     ...      ...                ...
# 3137      50       4         8     56      37  Wyoming  Sweetwater County
# 3138      50       4         8     56      39  Wyoming       Teton County
# 3139      50       4         8     56      41  Wyoming       Uinta County
# 3140      50       4         8     56      43  Wyoming    Washakie County
# 3141      50       4         8     56      45  Wyoming      Weston County
#
#       CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  \
# ...

# %%
sm4 = census.iloc[:,5:8]
sm4
# Out:
#        STNAME            CTYNAME  CENSUS2010POP
# 0     Alabama     Autauga County          54571
# 1     Alabama     Baldwin County         182265
# 2     Alabama     Barbour County          27457
# 3     Alabama        Bibb County          22915
# 4     Alabama      Blount County          57322
# ...       ...                ...            ...
# 3137  Wyoming  Sweetwater County          43806
# 3138  Wyoming       Teton County          21294
# 3139  Wyoming       Uinta County          21118
# 3140  Wyoming    Washakie County           8533
# 3141  Wyoming      Weston County           7208
#
# [3142 rows x 3 columns]

# %%
sm5 = sm4.groupby("STNAME")
c5 = sm4.sum("CENSUS2010POP")
c5
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-b701a931c177> in <module>
#       1 sm5 = sm4.groupby("STNAME")
# ----> 2 c5 = sm4.sum("CENSUS2010POP")
#       3 c5
#
# c:\users\rito\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\generic.py in stat_func(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   11182             skipna=skipna,
#   11183             numeric_only=numeric_only,
# > 11184             min_count=min_count,
#   11185         )
#   11186
#
# c:\users\rito\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\frame.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    7858         else:
#    7859             # TODO: Make other agg func handle axis=None properly
# -> 7860             axis = self._get_axis_number(axis)
# ...
