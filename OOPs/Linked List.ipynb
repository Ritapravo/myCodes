# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None

    def get_data(self):
        return self.data

    def set_data(self,data):
        self.data=data

    def get_next(self):
        return self.next

    def set_next(self,next_node):
        self.next = next_node

item_node=Node("Sugar")
print(item_node.get_data())
# Out:
# Sugar

# %%
class LinkedList:
    def __init__(self):
        self.head=None
        self.tail=None
    
    def get_head(self):
        return self.head
    
    def get_tail(self):
        return self.tail
    
    def add(self,data):
        new_node=Node(data)
        if(self.head is None):
            self.head=self.tail=new_node
        else:
            self.tail.set_next(new_node)
            self.tail=new_node
    
    def display(self):
        temp=self.head
        while(temp is not None):
            print(temp.get_data())
            temp=temp.get_next()
                                              
    #You can use the below __str__() to print the elements of the DS object while debugging
    def __str__(self):
        temp=self.head
        msg=[]
        while(temp is not None):
           msg.append(str(temp.get_data()))
           temp=temp.get_next()
        msg=" ".join(msg)
        msg="Linkedlist data(Head to Tail): "+ msg
        return msg

def count_nodes(biscuit_list):
    count=0
    n = biscuit_list.get_head()
    # Write your logic here
    while(n!= None):
        count+=1
        n = n.next
    return count

biscuit_list=LinkedList()
biscuit_list.add("Goodday")
biscuit_list.add("Bourbon")
biscuit_list.add("Hide&Seek")
biscuit_list.add("Nutrichoice")

print(count_nodes(biscuit_list))
print(LinkedList.__str__(biscuit_list))
# Out:
# 4
# Linkedlist data(Head to Tail): Goodday Bourbon Hide&Seek Nutrichoice

# %%
#DSA-Exer-2 #code from the course

class Node:
    def __init__(self,data):
        self.__data=data
        self.__next=None
    
    def get_data(self):
        return self.__data
    
    def set_data(self,data):
        self.__data=data
    
    def get_next(self):
        return self.__next
    
    def set_next(self,next_node):
        self.__next=next_node
    
class LinkedList:
    def __init__(self):
        self.__head=None
        self.__tail=None
    
    def get_head(self):
        return self.__head
    
    def get_tail(self):
        return self.__tail
    
    def add(self,data):
        new_node=Node(data)
        if(self.__head is None):
            self.__head=self.__tail=new_node
        else:
            self.__tail.set_next(new_node)
            self.__tail=new_node
    
    def display(self):
        temp=self.__head
        while(temp is not None):
            print(temp.get_data())
            temp=temp.get_next()
                                              
    #You can use the below __str__() to print the elements of the DS object while debugging
    def __str__(self):
        temp=self.__head
        msg=[]
        while(temp is not None):
           msg.append(str(temp.get_data()))
           temp=temp.get_next()
        msg=" ".join(msg)
        msg="Linkedlist data(Head to Tail): "+ msg
        return msg

def count_nodes(biscuit_list):
    count=0
    # Write your logic here
    n = biscuit_list.get_head()
    # Write your logic here
    while(n!= None):
        count+=1
        n = n.get_next()
    return count

biscuit_list=LinkedList()
biscuit_list.add("Goodday")
biscuit_list.add("Bourbon")
biscuit_list.add("Hide&Seek")
biscuit_list.add("Nutrichoice")

print(count_nodes(biscuit_list))
# Out:
# 4

# %%
class Node:
    def __init__(self,data):
        self.__data=data
        self.__next=None

    def get_data(self):
        return self.__data
    
    def set_data(self,data):
        self.__data=data
    
    def get_next(self):
        return self.__next
    
    def set_next(self,next_node):
        self.__next=next_node
    
class LinkedList:
    def __init__(self):
        self.__head=None
        self.__tail=None
    
    def get_head(self):
        return self.__head
    
    def get_tail(self):
        return self.__tail
    
    def add(self,data):
        new_node=Node(data)
        if(self.__head is None):
            self.__head=self.__tail=new_node
        else:
            self.__tail.set_next(new_node)
            self.__tail=new_node
            
    def display(self):
        temp=self.__head
        while(temp is not None):
            print(temp.get_data())
            temp=temp.get_next()
        #Remove pass and copy the code you had written to display the element(s).
    
    def find_node(self,data):
        n = list1.get_head()
        #found = False
        while(n!=None):
            d = n.get_data()
            if(d==data):
                return(n)
            n = n.get_next()
        return (n)
            
        #Remove pass and write the logic to find the node and return the node if found or return None.
                                            
    #You can use the below __str__() to print the elements of the DS object while debugging
    def __str__(self):
        temp=self.__head
        msg=[]
        while(temp is not None):
           msg.append(str(temp.get_data()))
           temp=temp.get_next()
        msg=" ".join(msg)
        msg="Linkedlist data(Head to Tail): "+ msg
        return msg


list1=LinkedList()
#biscuit_list.add("Goodday")
list1.add("Bourbon")
list1.add("Hide&Seek")
list1.add("Nutrichoice")
node=list1.find_node("Sugar")
if(node!=None):
    print("Node found")
else:
    print("Node not found")

# %%
class Solution:
    def addTwoNumbers(self, l1: ListNode, l2: ListNode) -> ListNode:
        t1 = l1
        t2 = l2
        c = 0
        li = []
        ans = listNode()
        t3 = ans
        while(t1!=None and t2!=None):
            a = t1.val
            b = t2.val
            t3.val = (a+b+c)%10
            t3 = t3.next
            #li.append((a+b+c)%10)
            c = (a+b+c)//10
            t1 = t1.next
            t2 = t2.next
        while(t1!=None):
            a = t1.val
            t3.val = (a+c)%10
            t3 = t3.next
            #li.append((a+c)%10)
            c = (a+c)//10
            t1 = t1.next
        while(t2 != None):
            b = t2.val
            t3.val = (b+c)%10
            t3 = t3.next
            #li.append((b+c)%10)
            c = (b+c)//10
            t2 = t2.next
        print(li)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9475d07c8035> in <module>
# ----> 1 class Solution:
#       2     def addTwoNumbers(self, l1: ListNode, l2: ListNode) -> ListNode:
#       3         t1 = l1
#       4         t2 = l2
#       5         c = 0
#
# <ipython-input-1-9475d07c8035> in Solution()
#       1 class Solution:
# ----> 2     def addTwoNumbers(self, l1: ListNode, l2: ListNode) -> ListNode:
#       3         t1 = l1
#       4         t2 = l2
#       5         c = 0
#
# NameError: name 'ListNode' is not defined

# %%
class Solution:
    def addTwoNumbers(self, l1: ListNode, l2: ListNode) -> ListNode:
        t1 = l1
        t2 = l2
        c = 0

        t3 = ListNode(0)
        ans = t3
        while(t1!=None and t2!=None):
            a = t1.val
            b = t2.val
            tmp = ListNode((a+b+c)%10)
          # t3.val = tmp.val
          # t3.next = ListNode((a+b+c)%10)
            t3.next = tmp
            
            t3 = t3.next
            #li.append((a+b+c)%10)
            c = (a+b+c)//10
            t1 = t1.next
            t2 = t2.next
        while(t1!=None):
            a = t1.val
            tmp = ListNode((a+c)%10)
            t3.next = tmp
            
            t3 = t3.next
            #li.append((a+c)%10)
            c = (a+c)//10
            t1 = t1.next
        while(t2 != None):
            b = t2.val
            tmp = ListNode((b+c)%10)
            t3.next = tmp
            
            t3 = t3.next
            #li.append((b+c)%10)
            c = (b+c)//10
            t2 = t2.next
        if(c!=0):
            t3.next = ListNode(c)
        return ans.next
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e02a39a29d2d> in <module>
# ----> 1 class Solution:
#       2     def addTwoNumbers(self, l1: ListNode, l2: ListNode) -> ListNode:
#       3         t1 = l1
#       4         t2 = l2
#       5         c = 0
#
# <ipython-input-2-e02a39a29d2d> in Solution()
#       1 class Solution:
# ----> 2     def addTwoNumbers(self, l1: ListNode, l2: ListNode) -> ListNode:
#       3         t1 = l1
#       4         t2 = l2
#       5         c = 0
#
# NameError: name 'ListNode' is not defined
